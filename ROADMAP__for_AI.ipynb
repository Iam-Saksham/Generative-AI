# %% [markdown]
# <a href="https://colab.research.google.com/github/Saksham22-kb/Generative-AI/blob/main/ROADMAP__for_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Agentic AI ZERO TO HERO

# %% [markdown]
# 1.Promt Engineering

# %% [markdown]
# 2.LLM fine-tuning

# %% [markdown]
# 3.Vector Database

# %% [markdown]
# 4.Embeddings

# %% [markdown]
# 5.Langchain orchestration

# %% [markdown]
# 6.Llamaindex

# %% [markdown]
# 7.Tool Calling

# %% [markdown]
# 8.MCPs

# %% [markdown]
# 9.Scalable Deployment

# %% [markdown]
# 10.Multimodal AI
